# %%
import numpy as np
import jax.numpy as jnp
from CartPoleJax import *
from Common import *
from Rollout import *
from RolloutControl import *
from ModelControl import *

# %%
initial_state = jnp.array([0.0, 0.0, np.pi, 0.0])
sigma_l = jnp.array([8, 4, 1, 2])
initial_guess = jnp.array([0, 0, 0, 0, 0])

# %%
p, pred_loss = true_repeated_fit_policy(initial_state, sigma_l, 500, 3.0)
print(p)
print(pred_loss)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p, pred_loss = true_repeated_fit_policy(initial_state, sigma_l, 1000, 3.0)
#       2 print(p)
#       3 print(pred_loss)
#
# File ~/work/RolloutControl.py:149, in true_repeated_fit_policy(initial_state, sigma_l, samples, end_time)
#     146 best_loss = float('inf')
#     147 best_p = None
# --> 149 for i in range(samples):
#     150     p_rand, loss_rand = true_fit_policy(initial_state, guesses[i], sigma_l, end_time)
#     151     if loss_rand < best_loss:
#
# File ~/work/RolloutControl.py:132, in true_fit_policy(initial_state, initial_guess, sigma_l, horizon, dt)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ...

# %%
state_array, total_loss = true_policy_rollout(initial_state, p, sigma_l, 3.0)
print(total_loss)

axis_names = ['Cart Location (m)','Cart Velocity (m/s)','Pole Angle (rad)','Pole Velocity (rad/s)', 'Force (N)', 'Time (s)']

plotGraph(state_array, -1, 0, axis_names)
plotGraph(state_array, -1, 1, axis_names)
plotGraph(state_array, -1, 2, axis_names)
plotGraph(state_array, -1, 3, axis_names)
plotGraph(state_array, 2, 3, axis_names)
plotGraph(state_array, 2, 1, axis_names)
plotGraph(state_array, -1, -2, axis_names)
# Out:
# 6.1989274
# /root/work/Rollout.py:43: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
p_scan(initial_state, p, sigma_l, 2, -20, 20, 5)

# %%
A = load_jnp_array("data_JC/A")
b = load_jnp_array("data_JC/b")
X_basis = load_jnp_array("data_C2/X_basis")
alpha = load_jnp_array("data_C2/alpha")
sigma = load_jnp_array("data_C2/sigma")

# %%
state_array, total_loss = joint_policy_rollout(initial_state, p, sigma_l, A, b, X_basis, alpha, sigma, 5.0)
print(total_loss)

axis_names = ['Cart Location (m)','Cart Velocity (m/s)','Pole Angle (rad)','Pole Velocity (rad/s)', 'Force (N)', 'Time (s)']

plotGraph(state_array, -1, 0, axis_names)
plotGraph(state_array, -1, 1, axis_names)
plotGraph(state_array, -1, 2, axis_names)
plotGraph(state_array, -1, 3, axis_names)
plotGraph(state_array, 2, 3, axis_names)
plotGraph(state_array, 2, 1, axis_names)
plotGraph(state_array, -1, -2, axis_names)
# Out:
# 50.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=58725ef8-9a26-4e31-9e4c-5d3613b1a28f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
